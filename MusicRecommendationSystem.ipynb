# %%
import sklearn
import pandas
import seaborn

print("scikit-learn version:", sklearn.__version__)     # 1.1.3
print("pandas version:", pandas.__version__)            # 1.5.1
print("seaborn version:", seaborn.__version__)          # 0.12.1
# Out:
# scikit-learn version: 1.2.1
# pandas version: 1.5.3
# seaborn version: 0.12.2

# %% [markdown]
# # Data Provisioning

# %%
df = pandas.read_csv("/Users/scar/The Dev Area/GitHub/s4-individual/assets/SpotifyFeatures.csv")
df.sample(5)
# Out:
#              genre               artist_name                       track_name  \
# 89537      Hip-Hop  Rage Against The Machine      How I Could Just Kill a Man
# 112497         Pop                   Dr. Dog  Heart It Races - Dr Dog Version
# 85370          R&B                   Cherish                            Killa
# 24523   Electronic                 Ray Volpe                          Purpose
# 199306  Soundtrack              David Arnold               Who You Really Are
#
#                       track_id  popularity  acousticness  danceability  \
# 89537   4K1DB7EedHPuVnhVrnvf2U          61       0.00114         0.598
# 112497  2vupkXhwL4sNCRgNu72HCZ          64       0.44300         0.705
# 85370   5KzHTHTjftb7QFh5GicRnO          49       0.03320         0.796
# 24523   3JXLLE8mDMNoapN7wr9xEb          38       0.00418         0.671
# 199306  41ZRyGc2hgd2wTzyjzZs3i          35       0.23700         0.224
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 89537        244693   0.939          0.000009   G    0.2880    -3.663  Major
# 112497       233128   0.474          0.055300  A#    0.3380   -13.081  Major
# 85370        228973   0.705          0.000002   F    0.0809    -4.820  Minor
# 24523        230400   0.960          0.123000  G#    0.2020    -1.372  Major
# 199306       155773   0.273          0.905000   A    0.0867   -15.592  Minor
#
#         speechiness    tempo time_signature  valence
# 89537        0.1050   95.884            4/4    0.630
# 112497       0.0391   98.612            4/4    0.756
# 85370        0.0358  113.964            4/4    0.774
# 24523        0.1140  149.943            4/4    0.108
# 199306       0.0558  129.479            4/4    0.126

# %% [markdown]
# # Feature Selection

# %%
correlations = df.corr()
plot = seaborn.heatmap(correlations, cbar=True, annot=True, fmt=".1f")
# Out:
# /var/folders/v8/hj0s2wfd6xg6trfswy05p_7c0000gn/T/ipykernel_3406/472225529.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = df.corr()
